# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive/M6/DeepLineDP/script/line-level-baseline

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# !conda env create -f /content/drive/MyDrive/M6/DeepLineDP/requirements.yml

# %%
# %%bash
# source activate DeepLineDP_env
# pip install torch torchvision torchaudio

# %%
# !ls -la
# Out:
# total 69
# -rw------- 1 root root 20651 Jun 23 08:55 condacolab_install.log
# drwx------ 2 root root  4096 Apr 22 11:57 ErrorProne
# drwx------ 2 root root  4096 Apr 22 11:57 ngram
# -rw------- 1 root root  4356 Mar 14 15:16 RF-line-level.py
# -rw------- 1 root root 36665 Jun 23 09:10 run_RF.ipynb

# %% [markdown]
# ### Running of RF-line-level.py script - 2 min for each database
# output: /content/drive/MyDrive/M6/DeepLineDP/output/RF-line-level-result

# %%
# %%bash
# source activate DeepLineDP_env
# python RF-line-level.py activemq
# Out:
# load Word2Vec for activemq finished
# prepare data finished
# finished training model of activemq
# load Word2Vec for activemq finished
# load model finished
# finished activemq-5.2.0
# finished activemq-5.3.0
# finished activemq-5.8.0
# /usr/local/envs/DeepLineDP_env/lib/python3.7/site-packages/torch/nn/modules/rnn.py:70: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.001 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# 100%|██████████| 1203/1203 [00:11<00:00, 106.89it/s]
# /usr/local/envs/DeepLineDP_env/lib/python3.7/site-packages/torch/nn/modules/rnn.py:70: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.001 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# ...
# 100%|██████████| 102/102 [00:13<00:00,  7.50it/s]
